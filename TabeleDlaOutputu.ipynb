# %%
from tabulate import tabulate
from IPython.display import display, Markdown

# Twoje dane
data = {
    "Model": ["RandomForestClassifier", "HistGradientBoostingClassifier", "XGBClassifier", "CatBoostClassifier",
              "LGBMClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.99252, 0.99184, 0.99184, 0.99184, 0.99150, 0.98708, 0.97757, 0.85894],
    "Balanced Accuracy": [0.99298, 0.99229, 0.99229, 0.99221, 0.99199, 0.98739, 0.97798, 0.84897],
    "ROC AUC": [0.99298, 0.99229, 0.99229, 0.99221, 0.99199, 0.98739, 0.97798, 0.84897],
    "F1 Score": [0.99253, 0.99185, 0.99185, 0.99185, 0.99151, 0.98709, 0.97758, 0.85712],
    "Recall": [0.99252, 0.99184, 0.99184, 0.99184, 0.99150, 0.98708, 0.97757, 0.85894],
    "Precision": [0.99258, 0.99190, 0.99190, 0.99188, 0.99156, 0.98713, 0.97767, 0.86357],
    "MCC": [0.98490, 0.98352, 0.98352, 0.98351, 0.98284, 0.97387, 0.95465, 0.71630],
}

# time = "Time Taken": [0.81230, 1.88893, 0.51498, 7.75649, 0.47531, 1.14511, 0.55055, 0.48003]

# Dodaj tytuł
table_title = "# Wyniki klasyfikacji dla metody RFE (Recursive Feature Elmination)"

# Tworzenie tabeli w formie Markdown
table = tabulate(data, headers="keys", tablefmt="pipe", showindex=False)

with open('tabela_wynikow_rfe_pdf_mal.md', 'w') as file:
    file.write(f"{table_title}\n\n{table}")
# Wyświetlanie tabeli z tytułem w formie Markdown w jupyter notebook
display(Markdown(f"{table_title}\n\n{table}"))


# # Wykres słupkowy dla Time Taken
# plt.figure(figsize=(10, 6))
# plt.barh(data["Model"], time, color='green', edgecolor='black', linewidth=0.8)
# plt.title('Time Taken for Different Models')
# plt.xlabel('Time Taken (s)')
# plt.ylabel('Model')
# plt.tight_layout()
# plt.show()


import matplotlib.pyplot as plt

# Dane wejściowe
method_name = "FeatureWiz"
features = ["JS - Javascript", "endobj - endstream", "obj - endobj", "obj - stream", "stream - endstream",
            "stream - startxref", "endobj - stream", "obj - startxref", "obj - endstream", "endstream - startxref"]
correlation_values = [0.99384, 0.86231, 0.56475, 0.50703, 0.46475, 0.42797, 0.28412, 0.25870, 0.23487, 0.19767]

# Utwórz wykres kolumnowy
plt.figure(figsize=(10, 6))
plt.barh(features, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title('Najbardziej skorelowane cechy dla metody RFE (Recursive Feature Elmination)' )
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj wartości na słupkach
for index, value in enumerate(correlation_values):
    plt.text(value, index, f'{value:.5f}', ha='left', va='center', fontsize=8)

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1)

# Wyświetl wykres
plt.tight_layout()  # Zapewnia, że wszystkie elementy wykresu są widoczne

plt.savefig('rfe_most_correlated_features_for_pdfmal.png')
plt.show()
# Out:
# # Wyniki klasyfikacji dla metody RFE (Recursive Feature Elmination)
#
# | Model                          |   Accuracy |   Balanced Accuracy |   ROC AUC |   F1 Score |   Recall |   Precision |     MCC |
# |:-------------------------------|-----------:|--------------------:|----------:|-----------:|---------:|------------:|--------:|
# | RandomForestClassifier         |    0.99252 |             0.99298 |   0.99298 |    0.99253 |  0.99252 |     0.99258 | 0.9849  |
# | HistGradientBoostingClassifier |    0.99184 |             0.99229 |   0.99229 |    0.99185 |  0.99184 |     0.9919  | 0.98352 |
# | XGBClassifier                  |    0.99184 |             0.99229 |   0.99229 |    0.99185 |  0.99184 |     0.9919  | 0.98352 |
# | CatBoostClassifier             |    0.99184 |             0.99221 |   0.99221 |    0.99185 |  0.99184 |     0.99188 | 0.98351 |
# | LGBMClassifier                 |    0.9915  |             0.99199 |   0.99199 |    0.99151 |  0.9915  |     0.99156 | 0.98284 |
# ...

# %%
from tabulate import tabulate
from IPython.display import display, Markdown

# Twoje dane
data = {
    "Model": ["RandomForestClassifier", "LGBMClassifier", "CatBoostClassifier", "XGBClassifier",
              "HistGradientBoostingClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.97621, 0.97417, 0.97383, 0.97383, 0.97247, 0.95989, 0.94358, 0.89803],
    "Balanced Accuracy": [0.97609, 0.97381, 0.97372, 0.97314, 0.97213, 0.95995, 0.94288, 0.90330],
    "ROC AUC": [0.97609, 0.97381, 0.97372, 0.97314, 0.97213, 0.95995, 0.94288, 0.90330],
    "F1 Score": [0.97621, 0.97417, 0.97383, 0.97382, 0.97247, 0.95991, 0.94357, 0.89830],
    "Recall": [0.97621, 0.97417, 0.97383, 0.97383, 0.97247, 0.95989, 0.94358, 0.89803],
    "Precision": [0.97622, 0.97416, 0.97384, 0.97383, 0.97247, 0.95997, 0.94357, 0.90515],
    "MCC": [0.95190, 0.94776, 0.94710, 0.94706, 0.94432, 0.91902, 0.88589, 0.80228],
}

# Tytuł tabeli
table_title = "# Wyniki klasyfikacji dla metody SelectKBest(Anova)"

# Tworzenie tabeli w formie Markdown
table = tabulate(data, headers="keys", tablefmt="pipe", showindex=False)

# Wyświetlanie tabeli z tytułem w formie Markdown w jupyter notebook
display(Markdown(f"{table_title}\n\n{table}"))
# Out:
# # Wyniki klasyfikacji dla metody SelectKBest(Anova)
#
# | Model                          |   Accuracy |   Balanced Accuracy |   ROC AUC |   F1 Score |   Recall |   Precision |     MCC |
# |:-------------------------------|-----------:|--------------------:|----------:|-----------:|---------:|------------:|--------:|
# | RandomForestClassifier         |    0.97621 |             0.97609 |   0.97609 |    0.97621 |  0.97621 |     0.97622 | 0.9519  |
# | LGBMClassifier                 |    0.97417 |             0.97381 |   0.97381 |    0.97417 |  0.97417 |     0.97416 | 0.94776 |
# | CatBoostClassifier             |    0.97383 |             0.97372 |   0.97372 |    0.97383 |  0.97383 |     0.97384 | 0.9471  |
# | XGBClassifier                  |    0.97383 |             0.97314 |   0.97314 |    0.97382 |  0.97383 |     0.97383 | 0.94706 |
# | HistGradientBoostingClassifier |    0.97247 |             0.97213 |   0.97213 |    0.97247 |  0.97247 |     0.97247 | 0.94432 |
# ...

# %%
import pandas as pd
from IPython.display import display, HTML

# Twoje dane
data = {
    "Model": ["RandomForestClassifier", "HistGradientBoostingClassifier", "XGBClassifier", "CatBoostClassifier",
              "LGBMClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.99252, 0.99184, 0.99184, 0.99184, 0.9915, 0.98708, 0.97757, 0.85894],
    "Balanced Accuracy": [0.99298, 0.99229, 0.99229, 0.99221, 0.99199, 0.98739, 0.97798, 0.84897],
    "ROC AUC": [0.99298, 0.99229, 0.99229, 0.99221, 0.99199, 0.98739, 0.97798, 0.84897],
    "F1 Score": [0.99253, 0.99185, 0.99185, 0.99185, 0.99151, 0.98709, 0.97758, 0.85712],
    "Recall": [0.99252, 0.99184, 0.99184, 0.99184, 0.9915, 0.98708, 0.97757, 0.85894],
    "Precision": [0.99258, 0.9919, 0.9919, 0.99188, 0.99156, 0.98713, 0.97767, 0.86357],
    "MCC": [0.9849, 0.98352, 0.98352, 0.98351, 0.98284, 0.97387, 0.95465, 0.7163],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Stylizacja ramki danych dla efektu przypominającego tabelę Excel
styled_df = df.style.set_table_styles([{
    'selector': 'thead th',
    'props': [('border', '1px solid black')]
}])

# Wyświetlanie stylizowanej ramki danych
display(HTML(styled_df.render()))
# Out:
# C:\Users\earth\AppData\Local\Temp\ipykernel_1964\2483599308.py:27: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   display(HTML(styled_df.render()))
# <style type="text/css">
# #T_6aaa5 thead th {
#   border: 1px solid black;
# }
# </style>
# <table id="T_6aaa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6aaa5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6aaa5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6aaa5_level0_col2" class="col_heading level0 col2" >Balanced Accuracy</th>
#       <th id="T_6aaa5_level0_col3" class="col_heading level0 col3" >ROC AUC</th>
#       <th id="T_6aaa5_level0_col4" class="col_heading level0 col4" >F1 Score</th>
#       <th id="T_6aaa5_level0_col5" class="col_heading level0 col5" >Recall</th>
#       <th id="T_6aaa5_level0_col6" class="col_heading level0 col6" >Precision</th>
# ...

# %%
import pandas as pd

#DANE RFE DLA PDFMAL
# Twoje dane
data = {
    "Model": ["RandomForestClassifier", "HistGradientBoostingClassifier", "XGBClassifier", "CatBoostClassifier",
              "LGBMClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.99252, 0.99184, 0.99184, 0.99184, 0.9915, 0.98708, 0.97757, 0.85894],
    "Balanced Accuracy": [0.99298, 0.99229, 0.99229, 0.99221, 0.99199, 0.98739, 0.97798, 0.84897],
    "ROC AUC": [0.99298, 0.99229, 0.99229, 0.99221, 0.99199, 0.98739, 0.97798, 0.84897],
    "F1 Score": [0.99253, 0.99185, 0.99185, 0.99185, 0.99151, 0.98709, 0.97758, 0.85712],
    "Recall": [0.99252, 0.99184, 0.99184, 0.99184, 0.9915, 0.98708, 0.97757, 0.85894],
    "Precision": [0.99258, 0.9919, 0.9919, 0.99188, 0.99156, 0.98713, 0.97767, 0.86357],
    "MCC": [0.9849, 0.98352, 0.98352, 0.98351, 0.98284, 0.97387, 0.95465, 0.7163],
}

table_title = "# Wyniki klasyfikacji dla metody RFE (Recursive Feature Elmination)"

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Kopiowanie danych do schowka
df.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import pandas as pd

#DANE RFE DLA DARKNET 
# Twoje dane
data = {
    "Model": ["XGBClassifier", "CatBoostClassifier", "LGBMClassifier", "RandomForestClassifier",
              "HistGradientBoostingClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.98099, 0.98118, 0.98045, 0.97893, 0.97853, 0.96735, 0.93907, 0.86557],
    "Balanced Accuracy": [0.96262, 0.96211, 0.96138, 0.95832, 0.95772, 0.93298, 0.88386, 0.68277],
    "ROC AUC": [0.96262, 0.96211, 0.96138, 0.95832, 0.95772, 0.93298, 0.88386, 0.68277],
    "F1 Score": [0.98088, 0.98106, 0.98034, 0.97879, 0.97839, 0.96693, 0.93818, 0.84816],
    "Recall": [0.98099, 0.98118, 0.98045, 0.97893, 0.97853, 0.96735, 0.93907, 0.86557],
    "Precision": [0.98086, 0.98106, 0.98032, 0.97877, 0.97837, 0.96694, 0.93781, 0.85443],
    "MCC": [0.93564, 0.93626, 0.93381, 0.92859, 0.92724, 0.88839, 0.79054, 0.47857],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Kopiowanie danych do schowka
df.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import pandas as pd

#DANE DLA SELECTKBEST ANOVA DLA PDFMAL
# Twoje dane
data2 = {
    "Model": ["RandomForestClassifier", "LGBMClassifier", "CatBoostClassifier", "XGBClassifier",
              "HistGradientBoostingClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.97621, 0.97417, 0.97383, 0.97383, 0.97247, 0.95989, 0.94358, 0.89803],
    "Balanced Accuracy": [0.97609, 0.97381, 0.97372, 0.97314, 0.97213, 0.95995, 0.94288, 0.90330],
    "ROC AUC": [0.97609, 0.97381, 0.97372, 0.97314, 0.97213, 0.95995, 0.94288, 0.90330],
    "F1 Score": [0.97621, 0.97417, 0.97383, 0.97382, 0.97247, 0.95991, 0.94357, 0.89830],
    "Recall": [0.97621, 0.97417, 0.97383, 0.97383, 0.97247, 0.95989, 0.94358, 0.89803],
    "Precision": [0.97622, 0.97416, 0.97384, 0.97383, 0.97247, 0.95997, 0.94357, 0.90515],
    "MCC": [0.95190, 0.94776, 0.94710, 0.94706, 0.94432, 0.91902, 0.88589, 0.80228],
}

# Tworzenie ramki danych (DataFrame)
df2 = pd.DataFrame(data2)

# Kopiowanie danych do schowka
df2.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane wejściowe
method_name = "Method Name"
features = ["Idle Mean - Idle Max", "Idle Mean - Idle Min", "Idle Max - Idle Min", 
            "Flow Packets/s - Bwd Packets/s", "Packet Length Max - Packet Length Std", 
            "Flow IAT Mean - Flow IAT Min", "Flow Duration - Flow IAT Max", 
            "Packet Length Std - Subflow Bwd Bytes", "Total Length of Bwd Packet - Fwd Header Length", 
            "Flow IAT Mean - Flow IAT Max"]

correlation_values = [0.98469, 0.88116, 0.81826, 0.81031, 0.76373, 0.76007, 0.72809, 0.72022, 0.67685, 0.65076]

# Utwórz wykres kolumnowy
plt.figure(figsize=(10, 6))
plt.barh(features, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title('Najbardziej skorelowane cechy dla metody RFE (Recursive Feature Elimination)')
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj wartości na słupkach
for index, value in enumerate(correlation_values):
    plt.text(value, index, f'{value:.5f}', ha='left', va='center', fontsize=8)

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1)

# Wyświetl wykres
plt.tight_layout()  # Zapewnia, że wszystkie elementy wykresu są widoczne

plt.savefig('rfe_most_correlated_features.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane wejściowe
method_name = "Method Name"
features = ["Idle Mean - Idle Max", "Idle Mean - Idle Min", "Idle Max - Idle Min", 
            "Flow Packets/s - Bwd Packets/s", "Packet Length Max - Packet Length Std", 
            "Flow IAT Mean - Flow IAT Min", "Flow Duration - Flow IAT Max", 
            "Packet Length Std - Subflow Bwd Bytes", "Total Length of Bwd Packet - Fwd Header Length", 
            "Flow IAT Mean - Flow IAT Max"]

correlation_values = [0.98469, 0.88116, 0.81826, 0.81031, 0.76373, 0.76007, 0.72809, 0.72022, 0.67685, 0.65076]

# Utwórz wykres kolumnowy
plt.figure(figsize=(12, 8))
bars = plt.barh(features, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title('Najbardziej skorelowane cechy dla metody RFE (Recursive Feature Elimination)')
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj większe wartości na słupkach
for bar in bars:
    plt.text(bar.get_width() + 0.003, bar.get_y() + bar.get_height()/2, f'{bar.get_width():.5f}', 
             va='center', fontsize=10, ha='left', color='black')

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1)

# Wyświetl wykres
plt.tight_layout()  # Zapewnia, że wszystkie elementy wykresu są widoczne

plt.savefig('rfe_most_correlated_features.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane wejściowe
method_name = "SelectKBest(Anova)"
features = ["xref - trailer", "xref - startxref", "trailer - startxref", "obj - stream", "stream - Acroform",
            "obj - pageno", "stream - startxref", "startxref - Acroform", "stream - ObjStm", "ObjStm - Acroform"]
correlation_values = [0.96710, 0.61135, 0.59461, 0.50703, 0.48496, 0.45080, 0.42797, 0.42443, 0.36663, 0.35949]

# Utwórz wykres kolumnowy
plt.figure(figsize=(10, 6))
plt.barh(features, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title(f'Najbardziej skorelowane cechy dla metody {method_name}')
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj wartości na słupkach
for index, value in enumerate(correlation_values):
    plt.text(value, index, f'{value:.5f}', ha='left', va='center', fontsize=8)

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1)

# Wyświetl wykres
plt.tight_layout()  # Zapewnia, że wszystkie elementy wykresu są widoczne

plt.savefig('selectkbest_anova_most_correlated_features.png')
plt.show()

# %%
import pandas as pd

# Twoje dane
data3 = {
    "Model": ["XGBClassifier", "CatBoostClassifier", "RandomForestClassifier", "LGBMClassifier",
              "HistGradientBoostingClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.97478, 0.97442, 0.97272, 0.97279, 0.97133, 0.96051, 0.91827, 0.86773],
    "Balanced Accuracy": [0.94567, 0.94516, 0.94376, 0.94315, 0.94015, 0.91495, 0.84619, 0.69165],
    "ROC AUC": [0.94567, 0.94516, 0.94376, 0.94315, 0.94015, 0.91495, 0.84619, 0.69165],
    "F1 Score": [0.97448, 0.97412, 0.97245, 0.97249, 0.97100, 0.95977, 0.91702, 0.85286],
    "Recall": [0.97478, 0.97442, 0.97272, 0.97279, 0.97133, 0.96051, 0.91827, 0.86773],
    "Precision": [0.97454, 0.97417, 0.97243, 0.97250, 0.97101, 0.95989, 0.91628, 0.85568],
    "MCC": [0.91263, 0.91136, 0.90560, 0.90576, 0.90062, 0.86185, 0.71384, 0.48316],
}

# Tworzenie ramki danych (DataFrame)
df3 = pd.DataFrame(data3)

# Kopiowanie danych do schowka
df3.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import matplotlib.pyplot as plt

# Dane wejściowe
method_name = "FeatureWiz"
features = ["Bwd Packet Length Mean - Bwd Segment Size Avg", "Idle Mean - Idle Max",
            "Bwd Packet Length Mean - Subflow Bwd Bytes", "Bwd Segment Size Avg - Subflow Bwd Bytes",
            "Idle Mean - Idle Min", "Flow IAT Std - Flow IAT Max", "Idle Max - Idle Min",
            "Fwd Packet Length Min - Packet Length Min", "Protocol - Packet Length Min",
            "Average Packet Size - Subflow Bwd Bytes"]
correlation_values = [1.0, 0.98469, 0.97967, 0.97967, 0.88116, 0.85059, 0.81826, 0.78958, 0.7116, 0.65052]

# Utwórz wykres kolumnowy
plt.figure(figsize=(10, 6))
plt.barh(features, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title(f'Najbardziej skorelowane cechy dla metody {method_name}')
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj wartości na słupkach
for index, value in enumerate(correlation_values):
    plt.text(value, index, f'{value:.5f}', ha='left', va='center', fontsize=8)

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1)

# Wyświetl wykres
plt.tight_layout()  # Zapewnia, że wszystkie elementy wykresu są widoczne
plt.show()

# %%
#FeautureWiz
from featurewiz import featurewiz
from lazypredict.Supervised import LazyClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

target = 'Label'
features, train = featurewiz(dataset, target, corr_limit=0.7, verbose=2, sep=",", 
                             header=0, test_data="", feature_engg="", category_encoders="")
print(features)
X = dataset[features].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

imputer = SimpleImputer()
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

scaler = MinMaxScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train_std, X_test_std, y_train, y_test)
print(models)
# Out:
# Imported lazytransform v1.9.
#
# Imported featurewiz 0.4.8. Use the following syntax:
#     >>> wiz = FeatureWiz(feature_engg = '', nrows=None, transform_target=True, scalers="std",
#         		category_encoders="auto", add_missing=False, verbose=0)
#     >>> X_train_selected, y_train = wiz.fit_transform(X_train, y_train)
#     >>> X_test_selected = wiz.transform(X_test)
#     >>> selected_features = wiz.features
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 from lazypredict.Supervised import LazyClassifier
#       5 target = 'Label'
# ----> 6 features, train = featurewiz(dataset, target, corr_limit=0.7, verbose=2, sep=",", header=0, test_data="", feature_engg="", category_encoders="")
#       7 print(features)
#       8 X = dataset[features].to_numpy()
#
# NameError: name 'dataset' is not defined

# %%
import pandas as pd

# Dane z zadania
data3 = {
    "Model": ["XGBClassifier", "RandomForestClassifier", "HistGradientBoostingClassifier", "LGBMClassifier",
              "CatBoostClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.99082, 0.98946, 0.98912, 0.98878, 0.98742, 0.98640, 0.98029, 0.88477],
    "Balanced Accuracy": [0.99045, 0.98919, 0.98894, 0.98857, 0.98731, 0.98614, 0.98009, 0.87985],
    "ROC AUC": [0.99045, 0.98919, 0.98894, 0.98857, 0.98731, 0.98614, 0.98009, 0.87985],
    "F1 Score": [0.99082, 0.98946, 0.98912, 0.98878, 0.98742, 0.98640, 0.98028, 0.88400],
    "Recall": [0.99082, 0.98946, 0.98912, 0.98878, 0.98742, 0.98640, 0.98029, 0.88477],
    "Precision": [0.99084, 0.98947, 0.98912, 0.98879, 0.98742, 0.98641, 0.98028, 0.88777],
    "MCC": [0.98154, 0.97879, 0.97810, 0.97741, 0.97467, 0.97262, 0.96030, 0.77001],
}

# Tworzenie ramki danych (DataFrame)
df3 = pd.DataFrame(data3)

# Kopiowanie danych do schowka
df3.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
df3.to_clipboard(index=False, excel=True)
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import matplotlib.pyplot as plt

# Dane wejściowe
method_name = "FeatureWiz"
features = ["trailer - startxref", "obj - endobj", "obj - Colors", "obj - stream", "obj - pageno",
            "stream - startxref", "endobj - Colors", "stream - endobj", "stream - pageno", "obj - startxref"]
correlation_values = [0.59461, 0.56475, 0.56153, 0.50703, 0.45080, 0.42797, 0.31822, 0.28412, 0.28213, 0.25870]

# Utwórz wykres kolumnowy
plt.figure(figsize=(10, 6))
plt.barh(features, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title(f'Najbardziej skorelowane cechy dla metody {method_name}')
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj wartości na słupkach
for index, value in enumerate(correlation_values):
    plt.text(value, index, f'{value:.5f}', ha='left', va='center', fontsize=8)

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1)

# Wyświetl wykres
plt.tight_layout()  # Zapewnia, że wszystkie elementy wykresu są widoczne
plt.show()

# %%
import pandas as pd

# Dane z zadania
data = {
    "Model": ["XGBClassifier", "LGBMClassifier", "CatBoostClassifier", "HistGradientBoostingClassifier",
              "RandomForestClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.97992, 0.97899, 0.97896, 0.97637, 0.97767, 0.96482, 0.93612, 0.86471],
    "Balanced Accuracy": [0.96089, 0.95912, 0.95804, 0.95540, 0.95492, 0.92842, 0.88177, 0.68663],
    "ROC AUC": [0.96089, 0.95912, 0.95804, 0.95540, 0.95492, 0.92842, 0.88177, 0.68663],
    "F1 Score": [0.97981, 0.97887, 0.97882, 0.97625, 0.97749, 0.96436, 0.93538, 0.84848],
    "Recall": [0.97992, 0.97899, 0.97896, 0.97637, 0.97767, 0.96482, 0.93612, 0.86471],
    "Precision": [0.97979, 0.97884, 0.97880, 0.97620, 0.97749, 0.96435, 0.93496, 0.85283],
    "MCC": [0.93212, 0.92895, 0.92875, 0.92014, 0.92427, 0.87980, 0.78154, 0.47838],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Kopiowanie danych do schowka
df.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
df.to_clipboard(index=False, excel=True)
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import matplotlib.pyplot as plt

# Dane wejściowe
feature_names = ["Packet Length Max - Fwd Packet Length Max", "Fwd Header Length - Total Length of Bwd Packet",
                 "Bwd IAT Mean - Fwd IAT Min", "Fwd Packet Length Mean - Fwd Packet Length Max",
                 "Bwd IAT Std - Flow IAT Max", "FWD Init Win Bytes - Bwd Init Win Bytes",
                 "Fwd Header Length - Fwd Act Data Pkts", "Bwd IAT Mean - Flow IAT Max",
                 "Flow IAT Max - Bwd IAT Total", "Bwd IAT Total - Bwd IAT Std"]
correlation_values = [0.69002, 0.67685, 0.67117, 0.66046, 0.65984, 0.63157, 0.63068, 0.62472, 0.60978, 0.56500]

# Utwórz wykres kolumnowy
plt.figure(figsize=(10, 6))
plt.barh(feature_names, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title('Współczynnik korelacji dla 10 par cech wybranych przez narzędzie FeatureWiz')
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj wartości na słupkach
for index, value in enumerate(correlation_values):
    plt.text(value, index, f'{value:.5f}', ha='left', va='center', fontsize=8)

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1 + 0.3)

# Wyświetl wykres
plt.tight_layout()
plt.savefig('correlation_plot.png')
plt.show()

# %%
import pandas as pd

# Dane z zadania
data = {
    "Model": ["XGBClassifier", "LGBMClassifier", "HistGradientBoostingClassifier", "CatBoostClassifier",
              "RandomForestClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.99048, 0.99048, 0.99014, 0.98912, 0.98878, 0.98640, 0.97451, 0.91027],
    "Balanced Accuracy": [0.99053, 0.99047, 0.99022, 0.98922, 0.98885, 0.98666, 0.97452, 0.90902],
    "ROC AUC": [0.99053, 0.99047, 0.99022, 0.98922, 0.98885, 0.98666, 0.97452, 0.90902],
    "F1 Score": [0.99048, 0.99048, 0.99014, 0.98912, 0.98878, 0.98641, 0.97451, 0.91021],
    "Recall": [0.99048, 0.99048, 0.99014, 0.98912, 0.98878, 0.98640, 0.97451, 0.91027],
    "Precision": [0.99049, 0.99048, 0.99015, 0.98914, 0.98879, 0.98645, 0.97453, 0.91024],
    "MCC": [0.98083, 0.98083, 0.98015, 0.97810, 0.97741, 0.97266, 0.94867, 0.81907],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Kopiowanie danych do schowka
df.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import matplotlib.pyplot as plt

# Dane wejściowe
feature_names = ["xref - trailer", "endobj - endstream", "endstream - Acroform",
                 "endobj - pageno", "Javascript - trailer", "xref - Javascript",
                 "OpenAction - Acroform", "endobj - Acroform", "xref - pageno",
                 "pageno - trailer"]
correlation_values = [0.96710, 0.86231, 0.30158, 0.25353, 0.25085, 0.24179, 0.23688, 0.19049, 0.16244, 0.14308]

# Utwórz wykres kolumnowy
plt.figure(figsize=(10, 6))
plt.barh(feature_names, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title('Współczynnik korelacji dla 10 najbardziej skorelowanych cech dla metody WlasnaMetoda')
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj wartości na słupkach
for index, value in enumerate(correlation_values):
    plt.text(value, index, f'{value:.5f}', ha='left', va='center', fontsize=8)

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1)

# Wyświetl wykres
plt.tight_layout()
plt.savefig('correlation_plot_wlasna_metoda.png')
plt.show()

# %%
import pandas as pd

# Dane z zadania
data = {
    "Model": ["XGBClassifier", "RandomForestClassifier", "CatBoostClassifier", "LGBMClassifier",
              "HistGradientBoostingClassifier", "GradientBoostingClassifier", "AdaBoostClassifier", "LinearSVC"],
    "Accuracy": [0.96745, 0.96698, 0.96605, 0.96177, 0.95938, 0.93124, 0.90772, 0.86298],
    "Balanced Accuracy": [0.93823, 0.93709, 0.93503, 0.92949, 0.92404, 0.86105, 0.80600, 0.67809],
    "ROC AUC": [0.93823, 0.93709, 0.93503, 0.92949, 0.92404, 0.86105, 0.80600, 0.67809],
    "F1 Score": [0.96721, 0.96673, 0.96578, 0.96153, 0.95907, 0.92952, 0.90363, 0.84541],
    "Recall": [0.96745, 0.96698, 0.96605, 0.96177, 0.95938, 0.93124, 0.90772, 0.86298],
    "Precision": [0.96712, 0.96664, 0.96568, 0.96140, 0.95891, 0.92922, 0.90345, 0.85046],
    "MCC": [0.88902, 0.88738, 0.88412, 0.86980, 0.86134, 0.75936, 0.66895, 0.46496],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Kopiowanie danych do schowka
df.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import matplotlib.pyplot as plt

# Dane wejściowe
feature_names = ["Bwd Packet Length Mean - Subflow Bwd Bytes", 
                 "Packet Length Min - Fwd Packet Length Min", 
                 "Fwd Header Length - Bwd Packet/Bulk Avg", 
                 "Fwd IAT Min - Flow IAT Mean", 
                 "Subflow Fwd Bytes - Average Packet Size", 
                 "Average Packet Size - Subflow Bwd Bytes", 
                 "Bwd Packet Length Mean - Average Packet Size", 
                 "Fwd Header Length - Fwd Act Data Pkts", 
                 "Packet Length Min - FIN Flag Count", 
                 "Bwd Packet/Bulk Avg - Fwd Act Data Pkts"]

correlation_values = [0.97967, 0.78958, 0.78912, 0.78141, 0.73365, 0.65052, 0.64566, 0.63068, 0.47415, 0.46651]

# Utwórz wykres kolumnowy
plt.figure(figsize=(10, 6))
plt.barh(feature_names, correlation_values, color='skyblue')
plt.xlabel('Wartość korelacji')
plt.title('Współczynnik korelacji dla 10 najbardziej skorelowanych cech dla metody WlasnaMetoda')
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Dodaj wartości na słupkach
for index, value in enumerate(correlation_values):
    plt.text(value, index, f'{value:.5f}', ha='left', va='center', fontsize=8)

# Dostosuj zakres osi x, aby zmieścić wartości
plt.xlim(0, max(correlation_values) + 0.1)

# Wyświetl wykres
plt.tight_layout()
plt.savefig('correlation_plot_wlasna_metoda_2.png')
plt.show()

# %%
import pandas as pd

# Twoje dane
data = {
    "Metoda": ["RFE", "RFE", "SelectKBest", "SelectKBest", "FeatureWiz", "FeatureWiz", "Własna", "Własna"],
    "Zbior": ["Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022"],
    "Model": ["XGBClassifier", "RandomForestClassifier", "XGBClassifier", "RandomForestClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier"],
    "Accuracy": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Balanced Accuracy": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "ROC AUC": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "F1 Score": [0.98088, 0.99253, 0.97448, 0.97621, 0.97981, 0.99082, 0.96721, 0.99048],
    "Recall": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Precision": [0.98086, 0.99258, 0.97454, 0.97622, 0.97979, 0.99084, 0.96712, 0.99049],
    "MCC": [0.93564, 0.9849, 0.91263, 0.9519, 0.93212, 0.98154, 0.88902, 0.98083],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według zbioru i accuracy
df_sorted = df.sort_values(by="Accuracy", ascending=[True, False])

# Kopiowanie danych do schowka
df_sorted.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 21
#      18 df = pd.DataFrame(data)
#      20 # Sortowanie danych według zbioru i accuracy
# ---> 21 df_sorted = df.sort_values(by="Accuracy", ascending=[True, False])
#      23 # Kopiowanie danych do schowka
#      24 df_sorted.to_clipboard(index=False, excel=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# Twoje dane
data = {
    "Metoda": ["RFE", "RFE", "SelectKBest", "SelectKBest", "FeatureWiz", "FeatureWiz", "Własna", "Własna"],
    "Zbior": ["Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022"],
    "Model": ["XGBClassifier", "RandomForestClassifier", "XGBClassifier", "RandomForestClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier"],
    "Accuracy": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Balanced Accuracy": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "ROC AUC": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "F1 Score": [0.98088, 0.99253, 0.97448, 0.97621, 0.97981, 0.99082, 0.96721, 0.99048],
    "Recall": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Precision": [0.98086, 0.99258, 0.97454, 0.97622, 0.97979, 0.99084, 0.96712, 0.99049],
    "MCC": [0.93564, 0.9849, 0.91263, 0.9519, 0.93212, 0.98154, 0.88902, 0.98083],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Kopiowanie danych do schowka
df_sorted.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Twoje dane
data = {
    "Metoda": ["RFE", "RFE", "SelectKBest", "SelectKBest", "FeatureWiz", "FeatureWiz", "Własna", "Własna"],
    "Zbior": ["Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022"],
    "Model": ["XGBClassifier", "RandomForestClassifier", "XGBClassifier", "RandomForestClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier"],
    "Accuracy": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Balanced Accuracy": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "ROC AUC": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "F1 Score": [0.98088, 0.99253, 0.97448, 0.97621, 0.97981, 0.99082, 0.96721, 0.99048],
    "Recall": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Precision": [0.98086, 0.99258, 0.97454, 0.97622, 0.97979, 0.99084, 0.96712, 0.99049],
    "MCC": [0.93564, 0.9849, 0.91263, 0.9519, 0.93212, 0.98154, 0.88902, 0.98083],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Rysowanie wykresu punktowego
plt.figure(figsize=(10, 6))
plt.scatter(df_sorted["Zbior"] + " - " + df_sorted["Metoda"], df_sorted["Accuracy"], s=200, c='blue', alpha=0.7)
plt.title('Porównanie Accuracy dla różnych metod i zbiorów')
plt.xlabel('Zbiór - Metoda')
plt.ylabel('Accuracy')
plt.xticks(rotation=45, ha="right")

# Dodanie wartości na osi Y
for i, txt in enumerate(df_sorted["Accuracy"]):
    plt.annotate(f"{txt:.4f}", (df_sorted["Zbior"].iloc[i] + " - " + df_sorted["Metoda"].iloc[i], txt), textcoords="offset points", xytext=(0,5), ha='center')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Twoje dane
data = {
    "Metoda": ["RFE", "RFE", "SelectKBest", "SelectKBest", "FeatureWiz", "FeatureWiz", "Własna", "Własna"],
    "Zbior": ["Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022"],
    "Model": ["XGBClassifier", "RandomForestClassifier", "XGBClassifier", "RandomForestClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier"],
    "Accuracy": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Balanced Accuracy": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "ROC AUC": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "F1 Score": [0.98088, 0.99253, 0.97448, 0.97621, 0.97981, 0.99082, 0.96721, 0.99048],
    "Recall": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Precision": [0.98086, 0.99258, 0.97454, 0.97622, 0.97979, 0.99084, 0.96712, 0.99049],
    "MCC": [0.93564, 0.9849, 0.91263, 0.9519, 0.93212, 0.98154, 0.88902, 0.98083],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Rysowanie wykresu punktowego dla wszystkich miar
plt.figure(figsize=(12, 8))

metrics = ["Accuracy", "Balanced Accuracy", "ROC AUC", "F1 Score", "Recall", "Precision", "MCC"]
colors = ['blue', 'green', 'orange', 'purple', 'brown', 'pink', 'red']

for i, metric in enumerate(metrics):
    plt.scatter(df_sorted["Zbior"] + " - " + df_sorted["Metoda"], df_sorted[metric], s=200, c=colors[i], alpha=0.7, label=metric)

plt.title('Porównanie różnych miar dla różnych metod i zbiorów')
plt.xlabel('Zbiór - Metoda')
plt.ylabel('Wartość Miary')
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Twoje dane
data = {
    "Metoda": ["RFE", "RFE", "SelectKBest", "SelectKBest", "FeatureWiz", "FeatureWiz", "Własna", "Własna"],
    "Zbior": ["Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022"],
    "Model": ["XGBClassifier", "RandomForestClassifier", "XGBClassifier", "RandomForestClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier"],
    "Accuracy": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Balanced Accuracy": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "ROC AUC": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "F1 Score": [0.98088, 0.99253, 0.97448, 0.97621, 0.97981, 0.99082, 0.96721, 0.99048],
    "Recall": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Precision": [0.98086, 0.99258, 0.97454, 0.97622, 0.97979, 0.99084, 0.96712, 0.99049],
    "MCC": [0.93564, 0.9849, 0.91263, 0.9519, 0.93212, 0.98154, 0.88902, 0.98083],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Rysowanie wykresu słupkowego skumulowanego
plt.figure(figsize=(15, 10))

metrics = ["Accuracy", "Balanced Accuracy", "ROC AUC", "F1 Score", "Recall", "Precision", "MCC"]
colors = ['blue', 'green', 'orange', 'purple', 'brown', 'pink', 'red']

bar_width = 0.2  # Zwiększona szerokość słupków
bar_positions = np.arange(len(df_sorted))

for i, metric in enumerate(metrics):
    plt.bar(bar_positions + i * bar_width * 1.5, df_sorted[metric], width=bar_width, color=colors[i], label=metric, edgecolor='black', linewidth=0.7)

plt.title('Porównanie różnych miar dla różnych metod i zbiorów')
plt.xlabel('Zbiór - Metoda')
plt.ylabel('Wartość Miary')
plt.xticks(bar_positions + bar_width * (len(metrics) - 1) / 2, df_sorted["Zbior"] + " - " + df_sorted["Metoda"], rotation=45, ha="right")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Dostosowanie zakresu osi Y
plt.ylim(0.93, 1.0)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Twoje dane
data = {
    "Metoda": ["RFE", "RFE", "SelectKBest", "SelectKBest", "FeatureWiz", "FeatureWiz", "Własna", "Własna"],
    "Zbior": ["Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022"],
    "Model": ["XGBClassifier", "RandomForestClassifier", "XGBClassifier", "RandomForestClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier"],
    "Accuracy": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Balanced Accuracy": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "ROC AUC": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "F1 Score": [0.98088, 0.99253, 0.97448, 0.97621, 0.97981, 0.99082, 0.96721, 0.99048],
    "Recall": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Precision": [0.98086, 0.99258, 0.97454, 0.97622, 0.97979, 0.99084, 0.96712, 0.99049],
    "MCC": [0.93564, 0.9849, 0.91263, 0.9519, 0.93212, 0.98154, 0.88902, 0.98083],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Ustawienia seaborn dla lepszej czytelności
sns.set(style="whitegrid")

# Rysowanie wykresu punktowego dla wszystkich miar
plt.figure(figsize=(15, 10))

metrics = ["Accuracy", "Balanced Accuracy", "ROC AUC", "F1 Score", "Recall", "Precision", "MCC"]
colors = sns.color_palette("husl", len(metrics))

for i, metric in enumerate(metrics):
    plt.scatter(df_sorted["Zbior"] + " - " + df_sorted["Metoda"], df_sorted[metric], s=100, c=colors[i], alpha=0.7, label=metric, edgecolors='black', linewidths=0.5)
    for j, value in enumerate(df_sorted[metric]):
        plt.text(j, value, f'{value:.4f}', ha='center', va='bottom', fontsize=8, color=colors[i])

    plt.title(f'Porównanie różnych miar dla różnych metod i zbiorów - {metric}')
    plt.xlabel('Zbiór - Metoda')
    plt.ylabel(f'Wartość {metric}')
    plt.xticks(rotation=45, ha="right")
    plt.axhline(y=1.0, color='r', linestyle='--', linewidth=1, label='Wartość referencyjna')  # Dodanie linii referencyjnej
    plt.tight_layout()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.ylim(0.9, 1.0)
    plt.legend(loc="lower right", bbox_to_anchor=(1.0, 0.05))

plt.show()
# Out:
# C:\Users\earth\AppData\Local\Temp\ipykernel_13876\3818823012.py:35: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(df_sorted["Zbior"] + " - " + df_sorted["Metoda"], df_sorted[metric], s=100, c=colors[i], alpha=0.7, label=metric, edgecolors='black', linewidths=0.5)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Twoje dane
data = {
    "Metoda": ["RFE", "RFE", "SelectKBest", "SelectKBest", "FeatureWiz", "FeatureWiz", "Własna", "Własna"],
    "Zbior": ["Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022"],
    "Model": ["XGBClassifier", "RandomForestClassifier", "XGBClassifier", "RandomForestClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier", "XGBClassifier"],
    "Accuracy": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Balanced Accuracy": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "ROC AUC": [0.96262, 0.99298, 0.94567, 0.97609, 0.96089, 0.99045, 0.93823, 0.99053],
    "F1 Score": [0.98088, 0.99253, 0.97448, 0.97621, 0.97981, 0.99082, 0.96721, 0.99048],
    "Recall": [0.98099, 0.99252, 0.97478, 0.97621, 0.97992, 0.99082, 0.96745, 0.99048],
    "Precision": [0.98086, 0.99258, 0.97454, 0.97622, 0.97979, 0.99084, 0.96712, 0.99049],
    "MCC": [0.93564, 0.9849, 0.91263, 0.9519, 0.93212, 0.98154, 0.88902, 0.98083],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Rysowanie wykresu słupkowego skumulowanego
plt.figure(figsize=(20, 10))

metrics = ["Accuracy", "Balanced Accuracy", "ROC AUC", "F1 Score", "Recall", "Precision", "MCC"]
colors = ['blue', 'green', 'orange', 'purple', 'brown', 'pink', 'red']

bar_width = 0.15  # Zwiększona szerokość słupków
bar_positions = np.arange(len(df_sorted["Zbior"].unique()))

unique_combinations = set(zip(df_sorted["Zbior"], df_sorted["Metoda"]))

for i, metric in enumerate(metrics):
    for j, (dataset, method) in enumerate(unique_combinations):
        subset = df_sorted[(df_sorted["Zbior"] == dataset) & (df_sorted["Metoda"] == method)]
        plt.bar(bar_positions + i * len(unique_combinations) * bar_width + j * bar_width, subset[metric], width=bar_width, color=colors[i], label=f"{dataset} - {method} - {metric}", edgecolor='black', linewidth=0.7)

plt.title('Porównanie różnych miar dla różnych metod i zbiorów')
plt.xlabel('Zbiór - Metoda')
plt.ylabel('Wartość Miary')
plt.xticks(bar_positions + bar_width * len(metrics) / 2, df_sorted["Zbior"].unique(), rotation=45, ha="right")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Dostosowanie zakresu osi Y
plt.ylim(0.93, 1.0)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane dla pliku PDFMal
pdfmal_methods = ['RFE', 'SelectKBest(Anova)', 'FeatureWiz', 'Wlasna']
pdfmal_scores = [0.77240, 0.86930, 0.64399, 0.69650]

# Dane dla Darknet
darknet_methods = ['RFE', 'SelectKBest(Anova)', 'FeatureWiz', 'Wlasna']
darknet_scores = [0.45479, 0.54224, 0.43690, 0.39400]

# Tworzenie wykresu słupkowego
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 10))

# Wykres dla pliku PDFMal
ax1.bar(pdfmal_methods, pdfmal_scores, color=['blue', 'green', 'orange', 'red'])
ax1.set_title('Metody dla pliku PDFMal')
ax1.set_ylabel('Średnia 10')

# Wykres dla Darknet
ax2.bar(darknet_methods, darknet_scores, color=['blue', 'green', 'orange', 'red'])
ax2.set_title('Metody dla Darknet')
ax2.set_ylabel('Średnia 10')

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane dla pliku PDFMal
pdfmal_methods = ['RFE', 'FeatureWiz', 'Wlasna',  'SelectKBest(Anova)',]
pdfmal_scores = [0.98490,
0.98154,
0.95190,
0.98083]


# Dane dla Darknet
darknet_methods = ['RFE', 'FeatureWiz','SelectKBest(Anova)', 'Wlasna']
darknet_scores = [0.93564,
0.93212,
0.91263,
0.88902]


# Tworzenie wykresu punktowego
plt.figure(figsize=(10, 6))

# Wykres dla pliku PDFMal
plt.scatter(pdfmal_methods, pdfmal_scores, color='blue', label='PDFMal')

# Dodanie wartości pod punktami dla pliku PDFMal
for i, txt in enumerate(pdfmal_scores):
    plt.annotate(f'{txt:.4f}', (pdfmal_methods[i], pdfmal_scores[i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Wykres dla Darknet
plt.scatter(darknet_methods, darknet_scores, color='red', label='Darknet')

# Dodanie wartości pod punktami dla Darknet
for i, txt in enumerate(darknet_scores):
    plt.annotate(f'{txt:.4f}', (darknet_methods[i], darknet_scores[i]), textcoords="offset points", xytext=(0, -15), ha='center')

# Dodanie etykiet i tytułów
plt.title('Porównanie średnich 10 par cech')
plt.xlabel('Nazwa metody')
plt.ylabel('Wartość ')
plt.legend()

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane dla pliku PDFMal
pdfmal_methods = ['RFE', 'SelectKBest(Anova)', 'FeatureWiz', 'Wlasna']
pdfmal_scores = [0.77240, 0.86930, 0.64399, 0.69650]

# Dane dla Darknet
darknet_methods = ['RFE', 'SelectKBest(Anova)', 'FeatureWiz', 'Wlasna']
darknet_scores = [0.45479, 0.54224, 0.43690, 0.39400]

# Tworzenie wykresu punktowego
plt.figure(figsize=(10, 6))

# Wykres dla pliku PDFMal
plt.scatter(pdfmal_methods, pdfmal_scores, color='blue', label='PDFMal')

# Dodanie wartości pod punktami dla pliku PDFMal
for i, txt in enumerate(pdfmal_scores):
    plt.annotate(f'{txt:.4f}', (pdfmal_methods[i], pdfmal_scores[i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Wykres dla Darknet
plt.scatter(darknet_methods, darknet_scores, color='red', label='Darknet')

# Dodanie wartości pod punktami dla Darknet
for i, txt in enumerate(darknet_scores):
    plt.annotate(f'{txt:.4f}', (darknet_methods[i], darknet_scores[i]), textcoords="offset points", xytext=(0, -15), ha='center')

# Dodanie linii łączącej punkty
plt.plot(pdfmal_methods, pdfmal_scores, linestyle='dashed', color='blue', linewidth=1)
plt.plot(darknet_methods, darknet_scores, linestyle='dashed', color='red', linewidth=1)

# Dodanie etykiet i tytułów
plt.title('Porównanie średnich 10 dla różnych metod')
plt.xlabel('Metoda')
plt.ylabel('Średnia 10')
plt.legend()

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane dla pliku PDFMal
pdfmal_methods = ['RFE', 'SelectKBest(Anova)', 'FeatureWiz', 'Wlasna']
pdfmal_scores = [0.77240, 0.86930, 0.64399, 0.69650]

# Dane dla Darknet
darknet_methods = ['RFE', 'SelectKBest(Anova)', 'FeatureWiz', 'Wlasna']
darknet_scores = [0.45479, 0.54224, 0.43690, 0.39400]

# Tworzenie wykresu punktowego
plt.figure(figsize=(10, 6))

# Wykres dla pliku PDFMal
plt.scatter(pdfmal_methods, pdfmal_scores, color='blue', label='PDFMal')

# Dodanie wartości pod punktami dla pliku PDFMal
for i, txt in enumerate(pdfmal_scores):
    plt.annotate(f'{txt:.4f}', (pdfmal_methods[i], pdfmal_scores[i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Wykres dla Darknet
plt.scatter(darknet_methods, darknet_scores, color='red', label='Darknet')

# Dodanie wartości pod punktami dla Darknet
for i, txt in enumerate(darknet_scores):
    plt.annotate(f'{txt:.4f}', (darknet_methods[i], darknet_scores[i]), textcoords="offset points", xytext=(0, -15), ha='center')

# Dodanie linii łączącej punkty
plt.plot(pdfmal_methods, pdfmal_scores, linestyle='dashed', color='blue', linewidth=1, label='Linia łącząca PDFMal')
plt.plot(darknet_methods, darknet_scores, linestyle='dashed', color='red', linewidth=1, label='Linia łącząca Darknet')

# Dodanie etykiet i tytułów
plt.title('Porównanie średnich 10 par cech')
plt.xlabel('Nazwa metody')
plt.ylabel('Średnia korelacja z 10 par')
plt.legend()

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import matplotlib.pyplot as plt

metody = ["RFE", "FeatureWiz", "Własna", "RFE", "FeatureWiz", "SelectKBest", "SelectKBest", "Własna"]
mcc = [0.98490, 0.98154, 0.98083, 0.93564, 0.93212, 0.95190, 0.91263, 0.88902]

# Podział danych na grupy według metody
grupy = {}
for metoda, wynik in zip(metody, mcc):
    if metoda not in grupy:
        grupy[metoda] = []
    grupy[metoda].append(wynik)

# Tworzenie wykresu
fig, ax = plt.subplots()
for metoda, wyniki in grupy.items():
    ax.plot([metoda]*len(wyniki), wyniki, marker='o', linestyle='-', label=metoda)

ax.set_xlabel('Metoda')
ax.set_ylabel('MCC')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Dane
data = {
    'Zbior': ['PDFMal2022', 'PDFMal2022', 'PDFMal2022', 'Darknet2020', 'Darknet2020', 'PDFMal2022', 'Darknet2020', 'Darknet2020'],
    'Model': ['RandomForestClassifier', 'XGBClassifier', 'XGBClassifier', 'XGBClassifier', 'XGBClassifier', 'RandomForestClassifier', 'XGBClassifier', 'XGBClassifier'],
    'Metoda': ['RFE', 'FeatureWiz', 'Własna', 'RFE', 'FeatureWiz', 'SelectKBest', 'SelectKBest', 'Własna'],
    'MCC': [0.98490, 0.98154, 0.98083, 0.93564, 0.93212, 0.95190, 0.91263, 0.88902]
}

df = pd.DataFrame(data)

# Tworzenie wykresu punktowego
plt.figure(figsize=(12, 8))

# Wykres punktowy
plt.scatter(df['Metoda'], df['MCC'], c=df['Zbior'].apply(lambda x: 'blue' if x == 'PDFMal2022' else 'red'), s=200, alpha=0.7)

# Dodanie wartości pod punktami
for i, txt in enumerate(df['MCC']):
    plt.annotate(f'{txt:.5f}', (df['Metoda'][i], df['MCC'][i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Dodanie etykiet i tytułów
plt.title('Wykres punktowy dla MCC dla różnych metod i zbiorów')
plt.xlabel('Metoda')
plt.ylabel('MCC')
plt.legend(['PDFMal2022', 'Darknet2020'])

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Dane
data = {
    'Zbior': ['PDFMal2022', 'PDFMal2022', 'PDFMal2022', 'Darknet2020', 'Darknet2020', 'PDFMal2022', 'Darknet2020', 'Darknet2020'],
    'Model': ['RandomForestClassifier', 'XGBClassifier', 'XGBClassifier', 'XGBClassifier', 'XGBClassifier', 'RandomForestClassifier', 'XGBClassifier', 'XGBClassifier'],
    'Metoda': ['RFE', 'FeatureWiz', 'Własna', 'RFE', 'FeatureWiz', 'SelectKBest', 'SelectKBest', 'Własna'],
    'MCC': [0.98490, 0.98154, 0.98083, 0.93564, 0.93212, 0.95190, 0.91263, 0.88902]
}

df = pd.DataFrame(data)

# Tworzenie wykresu punktowego
plt.figure(figsize=(12, 8))

# Wykres punktowy
plt.scatter(df['Metoda'], df['MCC'], c=df['Zbior'].apply(lambda x: 'blue' if x == 'PDFMal2022' else 'red'), s=200, alpha=0.7)

# Dodanie wartości pod punktami
for i, txt in enumerate(df['MCC']):
    plt.annotate(f'{txt:.5f}', (df['Metoda'][i], df['MCC'][i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Dodanie linii łączącej punkty dla tych samych metod
for method in set(df['Metoda']):
    method_df = df[df['Metoda'] == method]
    plt.plot(method_df['Zbior'], method_df['MCC'], marker='o', label=method)

# Dodanie etykiet i tytułów
plt.title('Wykres punktowy dla MCC dla różnych metod i zbiorów z linią łączącą punkty')
plt.xlabel('Metoda')
plt.ylabel('MCC')
plt.legend()

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane dla pliku PDFMal
pdfmal_methods = ['RFE', 'SelectKBest(Anova)', 'FeatureWiz', 'Wlasna']
pdfmal_scores = [0.77240, 0.86930, 0.64399, 0.69650]

# Dane dla Darknet
darknet_methods = ['RFE', 'SelectKBest(Anova)', 'FeatureWiz', 'Wlasna']
darknet_scores = [0.45479, 0.54224, 0.43690, 0.39400]

# Tworzenie wykresu punktowego
plt.figure(figsize=(10, 6))

# Wykres dla pliku PDFMal
plt.scatter(pdfmal_methods, pdfmal_scores, color='blue', label='PDFMal')

# Dodanie wartości pod punktami dla pliku PDFMal
for i, txt in enumerate(pdfmal_scores):
    plt.annotate(f'{txt:.4f}', (pdfmal_methods[i], pdfmal_scores[i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Wykres dla Darknet
plt.scatter(darknet_methods, darknet_scores, color='red', label='Darknet')

# Dodanie wartości pod punktami dla Darknet
for i, txt in enumerate(darknet_scores):
    plt.annotate(f'{txt:.4f}', (darknet_methods[i], darknet_scores[i]), textcoords="offset points", xytext=(0, -15), ha='center')

# Dodanie linii łączącej punkty
plt.plot(pdfmal_methods, pdfmal_scores, linestyle='dashed', color='blue', linewidth=1, label='Linia łącząca PDFMal')
plt.plot(darknet_methods, darknet_scores, linestyle='dashed', color='red', linewidth=1, label='Linia łącząca Darknet')

# Dodanie etykiet i tytułów
plt.title('Porównanie średnich 10 par cech')
plt.xlabel('Nazwa metody')
plt.ylabel('Średnia korelacja z 10 par')
plt.legend()

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane dla pliku PDFMal
pdfmal_methods = ['RFE', 'FeatureWiz', 'Wlasna', 'SelectKBest(Anova)']
pdfmal_scores = [0.98490, 0.98154, 0.95190, 0.98083]

# Dane dla Darknet
darknet_methods = ['RFE', 'FeatureWiz', 'Wlasna', 'SelectKBest(Anova)']
darknet_scores = [0.93564, 0.93212, 0.88902, 0.91263]

# Tworzenie wykresu punktowego
plt.figure(figsize=(10, 6))

# Wykres dla pliku PDFMal
plt.scatter(pdfmal_methods, pdfmal_scores, color='blue', label='PDFMal')

# Dodanie wartości pod punktami dla pliku PDFMal
for i, txt in enumerate(pdfmal_scores):
    plt.annotate(f'{txt:.4f}', (pdfmal_methods[i], pdfmal_scores[i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Łączenie liniami punktów tego samego koloru po kolei
for i in range(len(pdfmal_methods) - 1):
    plt.plot(pdfmal_methods[i:i+2], pdfmal_scores[i:i+2], linestyle='dashed', color='blue', linewidth=1)

# Wykres dla Darknet
plt.scatter(darknet_methods, darknet_scores, color='red', label='Darknet')

# Dodanie wartości pod punktami dla Darknet
for i, txt in enumerate(darknet_scores):
    plt.annotate(f'{txt:.4f}', (darknet_methods[i], darknet_scores[i]), textcoords="offset points", xytext=(0, -15), ha='center')

# Łączenie liniami punktów tego samego koloru po kolei
for i in range(len(darknet_methods) - 1):
    plt.plot(darknet_methods[i:i+2], darknet_scores[i:i+2], linestyle='dashed', color='red', linewidth=1)

# Dodanie etykiet i tytułów
plt.title('Porównanie średnich 10 par cech')
plt.xlabel('Nazwa metody')
plt.ylabel('Wartość ')
plt.legend()

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import matplotlib.pyplot as plt

# Dane dla pliku PDFMal
pdfmal_methods = ["PDFMal2022", "PDFMal2022", "PDFMal2022", "PDFMal2022","Darknet2020", "Darknet2020", "Darknet2020", "Darknet2020"]
pdfmal_scores = [0.99184,
0.99014,
0.98912,
0.97853,
0.97637,
0.97247,
0.97133,
0.95938]



# Dane dla Darknet
darknet_methods = ["PDFMal2022", "PDFMal2022", "PDFMal2022", "PDFMal2022","Darknet2020", "Darknet2020", "Darknet2020", "Darknet2020"]
darknet_scores = [0.91027,
0.89803,
0.88477,
0.85894,
0.86773,
0.86557,
0.86471,
0.86298]

# Tworzenie wykresu punktowego
plt.figure(figsize=(10, 6))

# Wykres dla pliku PDFMal
plt.scatter(pdfmal_methods, pdfmal_scores, color='blue', label='XGBClassifier')

# Dodanie wartości pod punktami dla pliku PDFMal
for i, txt in enumerate(pdfmal_scores):
    plt.annotate(f'{txt:.4f}', (pdfmal_methods[i], pdfmal_scores[i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Wykres dla Darknet
plt.scatter(darknet_methods, darknet_scores, color='red', label='LinearSVC')

# Dodanie wartości pod punktami dla Darknet
for i, txt in enumerate(darknet_scores):
    plt.annotate(f'{txt:.4f}', (darknet_methods[i], darknet_scores[i]), textcoords="offset points", xytext=(0, -15), ha='center')

# Dodanie linii łączącej punkty
plt.plot(pdfmal_methods, pdfmal_scores, linestyle='dashed', color='blue', linewidth=1, label='Linia łącząca PDFMal')
plt.plot(darknet_methods, darknet_scores, linestyle='dashed', color='red', linewidth=1, label='Linia łącząca Darknet')

# Dodanie etykiet i tytułów
plt.title('Porównanie wyników MCC dla każdej z metod selekcji cech')
plt.xlabel('Nazwa metody')
plt.ylabel('Wartość Współczynnika korelacji Matthewsa')
plt.legend()

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import pandas as pd

# Twoje dane
data = {
    "Metoda": ["RFE", "RFE", "SelectKBest", "SelectKBest", "FeatureWiz", "FeatureWiz", "Własna", "Własna"],
    "Zbior": ["Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022", "Darknet2020", "PDFMal2022"],
    "Accuracy": [0.99184, 0.97853, 0.97247, 0.97133, 0.98912, 0.97637, 0.99014, 0.95938],
    "Balanced Accuracy": [0.99229, 0.95772, 0.97213, 0.94015, 0.98894, 0.9554, 0.99022, 0.92404],
    "ROC AUC": [0.99229, 0.95772, 0.97213, 0.94015, 0.98894, 0.9554, 0.99022, 0.92404],
    "F1 Score": [0.99185, 0.97839, 0.97247, 0.971, 0.98912, 0.97625, 0.99014, 0.95907],
    "Recall": [0.99184, 0.97853, 0.97247, 0.97133, 0.98912, 0.97637, 0.99014, 0.95938],
    "Precision": [0.9919, 0.97837, 0.97247, 0.97101, 0.98912, 0.9762, 0.99015, 0.95891],
    "MCC": [0.98352, 0.92724, 0.94432, 0.90062, 0.9781, 0.92014, 0.98015, 0.86134],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Kopiowanie danych do schowka
df_sorted.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import pandas as pd

# Twoje dane
data = {
    "Metoda": ["RFE", "FeatureWiz", "Własna", "RFE", "FeatureWiz", "SelectKBest", "SelectKBest", "Własna"],
    "Zbior": ["PDFMal2022", "PDFMal2022", "PDFMal2022", "Darknet2020", "Darknet2020", "Darknet2020", "PDFMal2022", "Darknet2020"],
    "Accuracy": [0.99184, 0.98912, 0.99014, 0.97853, 0.97637, 0.97247, 0.97133, 0.95938],
    "Balanced Accuracy": [0.99229, 0.98894, 0.99022, 0.95772, 0.9554, 0.97213, 0.94015, 0.92404],
    "ROC AUC": [0.99229, 0.98894, 0.99022, 0.95772, 0.9554, 0.97213, 0.94015, 0.92404],
    "F1 Score": [0.99185, 0.98912, 0.99014, 0.97839, 0.97625, 0.97247, 0.971, 0.95907],
    "Recall": [0.99184, 0.98912, 0.99014, 0.97853, 0.97637, 0.97247, 0.97133, 0.95938],
    "Precision": [0.9919, 0.98912, 0.99015, 0.97837, 0.9762, 0.97247, 0.97101, 0.95891],
    "MCC": [0.98352, 0.9781, 0.98015, 0.92724, 0.92014, 0.94432, 0.90062, 0.86134],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Kopiowanie danych do schowka
df_sorted.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import pandas as pd

# Twoje dane
data = {
    "Metoda": ["RFE", "FeatureWiz", "Własna", "RFE", "FeatureWiz", "SelectKBest", "SelectKBest", "Własna"],
    "Zbior": ["PDFMal2022", "PDFMal2022", "PDFMal2022", "Darknet2020", "Darknet2020", "PDFMal2022", "Darknet2020", "Darknet2020"],
    "Accuracy": [0.99252, 0.98946, 0.98878, 0.97893, 0.97767, 0.97621, 0.97272, 0.96698],
    "Balanced Accuracy": [0.99298, 0.98919, 0.98885, 0.95832, 0.95492, 0.97609, 0.94376, 0.93709],
    "ROC AUC": [0.99298, 0.98919, 0.98885, 0.95832, 0.95492, 0.97609, 0.94376, 0.93709],
    "F1 Score": [0.99253, 0.98946, 0.98878, 0.97879, 0.97749, 0.97621, 0.97245, 0.96673],
    "Recall": [0.99252, 0.98946, 0.98878, 0.97893, 0.97767, 0.97621, 0.97272, 0.96698],
    "Precision": [0.99258, 0.98947, 0.98879, 0.97877, 0.97749, 0.97622, 0.97243, 0.96664],
    "MCC": [0.98490, 0.97879, 0.97741, 0.92859, 0.92427, 0.95190, 0.90560, 0.88738],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Kopiowanie danych do schowka
df_sorted.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import pandas as pd

# Twoje dane
data = {
    "Metoda": ["Własna", "SelectKBest", "FeatureWiz", "RFE", "SelectKBest", "FeatureWiz", "RFE", "Własna"],
    "Zbior": ["PDFMal2022", "PDFMal2022", "PDFMal2022", "PDFMal2022", "Darknet2020", "Darknet2020", "Darknet2020", "Darknet2020"],
    "Accuracy": [0.91027, 0.89803, 0.88477, 0.85894, 0.86773, 0.86471, 0.86557, 0.86298],
    "Balanced Accuracy": [0.90902, 0.90330, 0.87985, 0.84897, 0.69165, 0.68663, 0.68277, 0.67809],
    "ROC AUC": [0.90902, 0.90330, 0.87985, 0.84897, 0.69165, 0.68663, 0.68277, 0.67809],
    "F1 Score": [0.91021, 0.89830, 0.88400, 0.85712, 0.85286, 0.84848, 0.84816, 0.84541],
    "Recall": [0.91027, 0.89803, 0.88477, 0.85894, 0.86773, 0.86471, 0.86557, 0.86298],
    "Precision": [0.91024, 0.90515, 0.88777, 0.86357, 0.85568, 0.85283, 0.85443, 0.85046],
    "MCC": [0.81907, 0.80228, 0.77001, 0.71630, 0.48316, 0.47838, 0.47857, 0.46496],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Kopiowanie danych do schowka
df_sorted.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dane dla pliku PDFMal
pdfmal_methods = ["HistGradientBoostingClassifier"]
pdfmal_scores = [0.99184, 0.99014, 0.98912, 0.97853, 0.97637, 0.97247, 0.97133, 0.95938]

# Dane dla Darknet
darknet_methods = ["LinearSVC"]
darknet_scores = [0.91027, 0.89803, 0.88477, 0.85894, 0.86773, 0.86557, 0.86471, 0.86298]

# Tworzenie wykresu punktowego
plt.figure(figsize=(10, 6))

# Wykres dla pliku PDFMal
plt.scatter(np.arange(len(pdfmal_methods)), pdfmal_scores, color='blue', label='HistGradientBoostingClassifier')

# Dodanie wartości pod punktami dla pliku PDFMal
for i, txt in enumerate(pdfmal_scores):
    plt.annotate(f'{txt:.4f}', (i, pdfmal_scores[i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Wykres dla Darknet
plt.scatter(np.arange(len(darknet_methods)), darknet_scores, color='red', label='LinearSVC')

# Dodanie wartości pod punktami dla Darknet
for i, txt in enumerate(darknet_scores):
    plt.annotate(f'{txt:.4f}', (i, darknet_scores[i]), textcoords="offset points", xytext=(0, -15), ha='center')

# Ustawienie etykiet dla osi x
plt.xticks(np.arange(len(pdfmal_methods)), pdfmal_methods + darknet_methods)

# Dodanie etykiet i tytułów
plt.title('Porównanie wyników MCC dla każdej z metod selekcji cech')
plt.xlabel('Nazwa metody')
plt.ylabel('Wartość Współczynnika korelacji Matthewsa')
plt.legend()

# Dostosowanie układu wykresu
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 16
#      13 plt.figure(figsize=(10, 6))
#      15 # Wykres dla pliku PDFMal
# ---> 16 plt.scatter(np.arange(len(pdfmal_methods)), pdfmal_scores, color='blue', label='HistGradientBoostingClassifier')
#      18 # Dodanie wartości pod punktami dla pliku PDFMal
#      19 for i, txt in enumerate(pdfmal_scores):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3684, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3665 @_copy_docstring_and_deprecators(Axes.scatter)
#    3666 def scatter(
#    3667     x: float | ArrayLike,
#    (...)
#    3682     **kwargs,
#    3683 ) -> PathCollection:
# -> 3684     __ret = gca().scatter(
#    3685         x,
#    3686         y,
#    3687         s=s,
# ...

# %%
import pandas as pd

# Twoje dane
data = {
    "Metoda": ["FeatureWiz", "RFE", "Własna", "SelectKBest", "RFE", "FeatureWiz", "SelectKBest", "Własna"],
    "Zbior": ["PDFMal2022", "PDFMal2022", "PDFMal2022", "PDFMal2022", "Darknet2020", "Darknet2020", "Darknet2020", "Darknet2020"],
    "Accuracy": [0.98029, 0.97757, 0.97451, 0.94358, 0.93907, 0.93612, 0.91827, 0.90772],
    "Balanced Accuracy": [0.98009, 0.97798, 0.97452, 0.94288, 0.88386, 0.88177, 0.84619, 0.80600],
    "ROC AUC": [0.98009, 0.97798, 0.97452, 0.94288, 0.88386, 0.88177, 0.84619, 0.80600],
    "F1 Score": [0.98028, 0.97758, 0.97451, 0.94357, 0.93818, 0.93538, 0.91702, 0.90363],
    "Recall": [0.98029, 0.97757, 0.97451, 0.94358, 0.93907, 0.93612, 0.91827, 0.90772],
    "Precision": [0.98028, 0.97767, 0.97453, 0.94357, 0.93781, 0.93496, 0.91628, 0.90345],
    "MCC": [0.9603, 0.95465, 0.94867, 0.88589, 0.79054, 0.78154, 0.71384, 0.66895],
}

# Tworzenie ramki danych (DataFrame)
df = pd.DataFrame(data)

# Sortowanie danych według accuracy w malejącej kolejności
df_sorted = df.sort_values(by="Accuracy", ascending=False)

# Kopiowanie danych do schowka
df_sorted.to_clipboard(index=False, excel=True)

print("Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.")
# Out:
# Dane zostały skopiowane do schowka. Teraz możesz wkleić je do programu Excel.
